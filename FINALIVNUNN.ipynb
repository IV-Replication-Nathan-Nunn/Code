# %%
import os
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

def load_data(file_name):
    current_dir = os.getcwd()
    os.chdir(current_dir)
    data = pd.read_csv(file_name)
    data.fillna(0, inplace=True)  # Update to properly handle NaNs as numeric zeros
    return data

def perform_iv_first_stage(data, instruments):
    X = data[instruments]
    X = sm.add_constant(X)
    y = data['ln_export_area']
    first_stage = sm.OLS(y, X).fit()
    data['predicted_ln_export_area'] = first_stage.predict(X)
    return first_stage, data

def perform_iv_second_stage(data, dependent_var):
    X = data[['predicted_ln_export_area']]
    X = sm.add_constant(X)
    y = data[dependent_var]
    second_stage = sm.OLS(y, X).fit()
    return second_stage

def run_analysis(entry_filename):
    if os.path.exists(entry_filename):
        data = load_data(entry_filename)
        instruments = ['atlantic_distance_minimum', 'indian_distance_minimum', 
                       'saharan_distance_minimum', 'red_sea_distance_minimum']

        # Perform IV regression for each year from 1990 to 2021
        iv_first_stage_results, updated_data = perform_iv_first_stage(data, instruments)
        results = []  # List to store results
        for year in range(1990, 2022):
            dependent_var = f'LNYR{year}'
            if dependent_var in updated_data.columns:
                iv_second_stage_results = perform_iv_second_stage(updated_data, dependent_var)
                results.append({
                    'Year': year,
                    'Coefficients': iv_second_stage_results.params,
                    'Standard Errors': iv_second_stage_results.bse
                })
                print(f'Results for {year}:')
                print(iv_second_stage_results.summary())
# Convert results to DataFrame
        results_df = pd.DataFrame(results)
        # Flatten the DataFrame columns if they are Series
        for col in ['Coefficients', 'Standard Errors']:
            results_df = results_df.join(pd.DataFrame(results_df.pop(col).values.tolist()).add_prefix(col + '_'))

        # Save to CSV
        results_df.to_csv('IV_analysis_results.csv', index=False)
def main():
    entry_filename = "mergedReplicationData3.csv"
    run_analysis(entry_filename)

if __name__ == "__main__":
    main()
# Out:
# Results for 1990:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR1990   R-squared:                       0.272
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     18.68
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           7.35e-05
# Time:                        13:27:05   Log-Likelihood:                -63.104
# No. Observations:                  52   AIC:                             130.2
# Df Residuals:                      50   BIC:                             134.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.3113      0.217     33.647      0.000       6.875       7.748
# predicted_ln_export_area    -0.2443      0.057     -4.322      0.000      -0.358      -0.131
# ==============================================================================
# Omnibus:                        0.156   Durbin-Watson:                   2.185
# Prob(Omnibus):                  0.925   Jarque-Bera (JB):                0.051
# Skew:                           0.071   Prob(JB):                        0.975
# Kurtosis:                       2.944   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 1991:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR1991   R-squared:                       0.253
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     16.93
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000144
# Time:                        13:27:05   Log-Likelihood:                -62.069
# No. Observations:                  52   AIC:                             128.1
# Df Residuals:                      50   BIC:                             132.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.3090      0.213     34.313      0.000       6.881       7.737
# predicted_ln_export_area    -0.2280      0.055     -4.115      0.000      -0.339      -0.117
# ==============================================================================
# Omnibus:                        0.119   Durbin-Watson:                   2.290
# Prob(Omnibus):                  0.942   Jarque-Bera (JB):                0.326
# Skew:                           0.003   Prob(JB):                        0.850
# Kurtosis:                       2.612   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 1992:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR1992   R-squared:                       0.214
# Model:                            OLS   Adj. R-squared:                  0.198
# Method:                 Least Squares   F-statistic:                     13.57
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000564
# Time:                        13:27:05   Log-Likelihood:                -66.801
# No. Observations:                  52   AIC:                             137.6
# Df Residuals:                      50   BIC:                             141.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.2094      0.233     30.901      0.000       6.741       7.678
# predicted_ln_export_area    -0.2236      0.061     -3.684      0.001      -0.346      -0.102
# ==============================================================================
# Omnibus:                        0.816   Durbin-Watson:                   2.260
# Prob(Omnibus):                  0.665   Jarque-Bera (JB):                0.807
# Skew:                           0.067   Prob(JB):                        0.668
# Kurtosis:                       2.405   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 1993:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR1993   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.218
# Method:                 Least Squares   F-statistic:                     15.26
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000282
# Time:                        13:27:05   Log-Likelihood:                -65.953
# No. Observations:                  52   AIC:                             135.9
# Df Residuals:                      50   BIC:                             139.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.2053      0.230     31.391      0.000       6.744       7.666
# predicted_ln_export_area    -0.2332      0.060     -3.906      0.000      -0.353      -0.113
# ==============================================================================
# Omnibus:                        1.827   Durbin-Watson:                   2.242
# Prob(Omnibus):                  0.401   Jarque-Bera (JB):                1.218
# Skew:                           0.030   Prob(JB):                        0.544
# Kurtosis:                       2.253   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 1994:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR1994   R-squared:                       0.297
# Model:                            OLS   Adj. R-squared:                  0.283
# Method:                 Least Squares   F-statistic:                     21.09
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           2.99e-05
# Time:                        13:27:05   Log-Likelihood:                -67.310
# No. Observations:                  52   AIC:                             138.6
# Df Residuals:                      50   BIC:                             142.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.2268      0.236     30.674      0.000       6.754       7.700
# predicted_ln_export_area    -0.2815      0.061     -4.592      0.000      -0.405      -0.158
# ==============================================================================
# Omnibus:                        1.592   Durbin-Watson:                   2.382
# Prob(Omnibus):                  0.451   Jarque-Bera (JB):                1.131
# Skew:                           0.027   Prob(JB):                        0.568
# Kurtosis:                       2.279   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 1995:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR1995   R-squared:                       0.264
# Model:                            OLS   Adj. R-squared:                  0.249
# Method:                 Least Squares   F-statistic:                     17.89
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           9.95e-05
# Time:                        13:27:05   Log-Likelihood:                -66.841
# No. Observations:                  52   AIC:                             137.7
# Df Residuals:                      50   BIC:                             141.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.2787      0.233     31.174      0.000       6.810       7.748
# predicted_ln_export_area    -0.2569      0.061     -4.230      0.000      -0.379      -0.135
# ==============================================================================
# Omnibus:                        1.135   Durbin-Watson:                   2.427
# Prob(Omnibus):                  0.567   Jarque-Bera (JB):                0.952
# Skew:                           0.049   Prob(JB):                        0.621
# Kurtosis:                       2.344   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 1996:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR1996   R-squared:                       0.245
# Model:                            OLS   Adj. R-squared:                  0.230
# Method:                 Least Squares   F-statistic:                     16.27
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000188
# Time:                        13:27:05   Log-Likelihood:                -67.057
# No. Observations:                  52   AIC:                             138.1
# Df Residuals:                      50   BIC:                             142.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.3036      0.234     31.151      0.000       6.833       7.774
# predicted_ln_export_area    -0.2460      0.061     -4.033      0.000      -0.369      -0.123
# ==============================================================================
# Omnibus:                        0.992   Durbin-Watson:                   2.427
# Prob(Omnibus):                  0.609   Jarque-Bera (JB):                0.914
# Skew:                           0.101   Prob(JB):                        0.633
# Kurtosis:                       2.383   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 1997:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR1997   R-squared:                       0.283
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     19.74
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           4.92e-05
# Time:                        13:27:05   Log-Likelihood:                -65.541
# No. Observations:                  52   AIC:                             135.1
# Df Residuals:                      50   BIC:                             139.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.3744      0.228     32.383      0.000       6.917       7.832
# predicted_ln_export_area    -0.2632      0.059     -4.443      0.000      -0.382      -0.144
# ==============================================================================
# Omnibus:                        0.764   Durbin-Watson:                   2.510
# Prob(Omnibus):                  0.682   Jarque-Bera (JB):                0.815
# Skew:                           0.131   Prob(JB):                        0.665
# Kurtosis:                       2.445   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 1998:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR1998   R-squared:                       0.253
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     16.91
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000146
# Time:                        13:27:05   Log-Likelihood:                -66.502
# No. Observations:                  52   AIC:                             137.0
# Df Residuals:                      50   BIC:                             140.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.2910      0.232     31.431      0.000       6.825       7.757
# predicted_ln_export_area    -0.2481      0.060     -4.112      0.000      -0.369      -0.127
# ==============================================================================
# Omnibus:                        1.168   Durbin-Watson:                   2.486
# Prob(Omnibus):                  0.558   Jarque-Bera (JB):                1.004
# Skew:                           0.110   Prob(JB):                        0.605
# Kurtosis:                       2.356   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 1999:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR1999   R-squared:                       0.282
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     19.60
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           5.20e-05
# Time:                        13:27:05   Log-Likelihood:                -66.719
# No. Observations:                  52   AIC:                             137.4
# Df Residuals:                      50   BIC:                             141.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.3435      0.233     31.525      0.000       6.876       7.811
# predicted_ln_export_area    -0.2683      0.061     -4.427      0.000      -0.390      -0.147
# ==============================================================================
# Omnibus:                        1.265   Durbin-Watson:                   2.517
# Prob(Omnibus):                  0.531   Jarque-Bera (JB):                1.036
# Skew:                          -0.096   Prob(JB):                        0.596
# Kurtosis:                       2.336   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2000:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2000   R-squared:                       0.342
# Model:                            OLS   Adj. R-squared:                  0.328
# Method:                 Least Squares   F-statistic:                     25.94
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           5.39e-06
# Time:                        13:27:05   Log-Likelihood:                -64.150
# No. Observations:                  52   AIC:                             132.3
# Df Residuals:                      50   BIC:                             136.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.4194      0.222     33.464      0.000       6.974       7.865
# predicted_ln_export_area    -0.2938      0.058     -5.093      0.000      -0.410      -0.178
# ==============================================================================
# Omnibus:                        0.525   Durbin-Watson:                   2.693
# Prob(Omnibus):                  0.769   Jarque-Bera (JB):                0.636
# Skew:                           0.041   Prob(JB):                        0.727
# Kurtosis:                       2.464   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2001:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2001   R-squared:                       0.330
# Model:                            OLS   Adj. R-squared:                  0.317
# Method:                 Least Squares   F-statistic:                     24.67
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           8.34e-06
# Time:                        13:27:05   Log-Likelihood:                -63.731
# No. Observations:                  52   AIC:                             131.5
# Df Residuals:                      50   BIC:                             135.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.3578      0.220     33.455      0.000       6.916       7.800
# predicted_ln_export_area    -0.2842      0.057     -4.967      0.000      -0.399      -0.169
# ==============================================================================
# Omnibus:                        0.385   Durbin-Watson:                   2.714
# Prob(Omnibus):                  0.825   Jarque-Bera (JB):                0.552
# Skew:                           0.137   Prob(JB):                        0.759
# Kurtosis:                       2.576   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2002:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2002   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     20.45
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           3.78e-05
# Time:                        13:27:05   Log-Likelihood:                -63.525
# No. Observations:                  52   AIC:                             131.0
# Df Residuals:                      50   BIC:                             135.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.3119      0.219     33.378      0.000       6.872       7.752
# predicted_ln_export_area    -0.2577      0.057     -4.522      0.000      -0.372      -0.143
# ==============================================================================
# Omnibus:                        0.357   Durbin-Watson:                   2.687
# Prob(Omnibus):                  0.837   Jarque-Bera (JB):                0.305
# Skew:                           0.175   Prob(JB):                        0.859
# Kurtosis:                       2.866   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2003:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2003   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     19.56
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           5.28e-05
# Time:                        13:27:05   Log-Likelihood:                -66.878
# No. Observations:                  52   AIC:                             137.8
# Df Residuals:                      50   BIC:                             141.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.4819      0.234     32.021      0.000       7.013       7.951
# predicted_ln_export_area    -0.2688      0.061     -4.422      0.000      -0.391      -0.147
# ==============================================================================
# Omnibus:                        0.331   Durbin-Watson:                   2.589
# Prob(Omnibus):                  0.847   Jarque-Bera (JB):                0.509
# Skew:                           0.070   Prob(JB):                        0.775
# Kurtosis:                       2.536   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2004:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2004   R-squared:                       0.259
# Model:                            OLS   Adj. R-squared:                  0.245
# Method:                 Least Squares   F-statistic:                     17.51
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000115
# Time:                        13:27:05   Log-Likelihood:                -69.469
# No. Observations:                  52   AIC:                             142.9
# Df Residuals:                      50   BIC:                             146.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.6237      0.246     31.043      0.000       7.130       8.117
# predicted_ln_export_area    -0.2673      0.064     -4.184      0.000      -0.396      -0.139
# ==============================================================================
# Omnibus:                        0.315   Durbin-Watson:                   2.609
# Prob(Omnibus):                  0.854   Jarque-Bera (JB):                0.497
# Skew:                           0.085   Prob(JB):                        0.780
# Kurtosis:                       2.552   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2005:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2005   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.236
# Method:                 Least Squares   F-statistic:                     16.72
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000157
# Time:                        13:27:05   Log-Likelihood:                -71.152
# No. Observations:                  52   AIC:                             146.3
# Df Residuals:                      50   BIC:                             150.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.7511      0.254     30.556      0.000       7.242       8.261
# predicted_ln_export_area    -0.2699      0.066     -4.089      0.000      -0.402      -0.137
# ==============================================================================
# Omnibus:                        0.561   Durbin-Watson:                   2.622
# Prob(Omnibus):                  0.755   Jarque-Bera (JB):                0.614
# Skew:                           0.229   Prob(JB):                        0.736
# Kurtosis:                       2.730   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2006:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2006   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.228
# Method:                 Least Squares   F-statistic:                     16.09
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000202
# Time:                        13:27:05   Log-Likelihood:                -71.443
# No. Observations:                  52   AIC:                             146.9
# Df Residuals:                      50   BIC:                             150.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.8494      0.255     30.771      0.000       7.337       8.362
# predicted_ln_export_area    -0.2662      0.066     -4.011      0.000      -0.399      -0.133
# ==============================================================================
# Omnibus:                        0.391   Durbin-Watson:                   2.643
# Prob(Omnibus):                  0.822   Jarque-Bera (JB):                0.475
# Skew:                           0.190   Prob(JB):                        0.788
# Kurtosis:                       2.727   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2007:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2007   R-squared:                       0.226
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     14.64
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000363
# Time:                        13:27:05   Log-Likelihood:                -71.504
# No. Observations:                  52   AIC:                             147.0
# Df Residuals:                      50   BIC:                             150.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.9424      0.255     31.099      0.000       7.429       8.455
# predicted_ln_export_area    -0.2542      0.066     -3.826      0.000      -0.388      -0.121
# ==============================================================================
# Omnibus:                        0.359   Durbin-Watson:                   2.655
# Prob(Omnibus):                  0.836   Jarque-Bera (JB):                0.353
# Skew:                           0.182   Prob(JB):                        0.838
# Kurtosis:                       2.823   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2008:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2008   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.184
# Method:                 Least Squares   F-statistic:                     12.50
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000888
# Time:                        13:27:05   Log-Likelihood:                -72.039
# No. Observations:                  52   AIC:                             148.1
# Df Residuals:                      50   BIC:                             152.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.0282      0.258     31.113      0.000       7.510       8.546
# predicted_ln_export_area    -0.2373      0.067     -3.536      0.001      -0.372      -0.103
# ==============================================================================
# Omnibus:                        0.980   Durbin-Watson:                   2.650
# Prob(Omnibus):                  0.613   Jarque-Bera (JB):                0.554
# Skew:                           0.248   Prob(JB):                        0.758
# Kurtosis:                       3.102   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2009:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2009   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     15.50
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000255
# Time:                        13:27:05   Log-Likelihood:                -66.714
# No. Observations:                  52   AIC:                             137.4
# Df Residuals:                      50   BIC:                             141.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.9969      0.233     34.334      0.000       7.529       8.465
# predicted_ln_export_area    -0.2386      0.061     -3.937      0.000      -0.360      -0.117
# ==============================================================================
# Omnibus:                        0.790   Durbin-Watson:                   2.710
# Prob(Omnibus):                  0.674   Jarque-Bera (JB):                0.394
# Skew:                           0.207   Prob(JB):                        0.821
# Kurtosis:                       3.103   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2010:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2010   R-squared:                       0.258
# Model:                            OLS   Adj. R-squared:                  0.243
# Method:                 Least Squares   F-statistic:                     17.36
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000122
# Time:                        13:27:05   Log-Likelihood:                -67.991
# No. Observations:                  52   AIC:                             140.0
# Df Residuals:                      50   BIC:                             143.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.1416      0.239     34.107      0.000       7.662       8.621
# predicted_ln_export_area    -0.2588      0.062     -4.167      0.000      -0.384      -0.134
# ==============================================================================
# Omnibus:                        0.379   Durbin-Watson:                   2.729
# Prob(Omnibus):                  0.827   Jarque-Bera (JB):                0.210
# Skew:                           0.155   Prob(JB):                        0.900
# Kurtosis:                       2.963   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2011:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2011   R-squared:                       0.241
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     15.85
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000222
# Time:                        13:27:05   Log-Likelihood:                -68.481
# No. Observations:                  52   AIC:                             141.0
# Df Residuals:                      50   BIC:                             144.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.2085      0.241     34.064      0.000       7.724       8.692
# predicted_ln_export_area    -0.2496      0.063     -3.981      0.000      -0.375      -0.124
# ==============================================================================
# Omnibus:                        1.210   Durbin-Watson:                   2.683
# Prob(Omnibus):                  0.546   Jarque-Bera (JB):                0.696
# Skew:                           0.273   Prob(JB):                        0.706
# Kurtosis:                       3.153   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2012:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2012   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.253
# Method:                 Least Squares   F-statistic:                     18.25
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           8.68e-05
# Time:                        13:27:05   Log-Likelihood:                -67.926
# No. Observations:                  52   AIC:                             139.9
# Df Residuals:                      50   BIC:                             143.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.2878      0.238     34.763      0.000       7.809       8.767
# predicted_ln_export_area    -0.2649      0.062     -4.272      0.000      -0.390      -0.140
# ==============================================================================
# Omnibus:                        1.031   Durbin-Watson:                   2.710
# Prob(Omnibus):                  0.597   Jarque-Bera (JB):                0.553
# Skew:                           0.242   Prob(JB):                        0.758
# Kurtosis:                       3.144   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2013:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2013   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     16.01
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000209
# Time:                        13:27:05   Log-Likelihood:                -68.842
# No. Observations:                  52   AIC:                             141.7
# Df Residuals:                      50   BIC:                             145.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.2466      0.243     33.986      0.000       7.759       8.734
# predicted_ln_export_area    -0.2526      0.063     -4.001      0.000      -0.379      -0.126
# ==============================================================================
# Omnibus:                        0.510   Durbin-Watson:                   2.583
# Prob(Omnibus):                  0.775   Jarque-Bera (JB):                0.360
# Skew:                           0.201   Prob(JB):                        0.835
# Kurtosis:                       2.928   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2014:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2014   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.224
# Method:                 Least Squares   F-statistic:                     15.72
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000234
# Time:                        13:27:05   Log-Likelihood:                -67.775
# No. Observations:                  52   AIC:                             139.6
# Df Residuals:                      50   BIC:                             143.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.2366      0.238     34.648      0.000       7.759       8.714
# predicted_ln_export_area    -0.2452      0.062     -3.965      0.000      -0.369      -0.121
# ==============================================================================
# Omnibus:                        0.644   Durbin-Watson:                   2.566
# Prob(Omnibus):                  0.725   Jarque-Bera (JB):                0.450
# Skew:                           0.226   Prob(JB):                        0.798
# Kurtosis:                       2.946   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2015:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2015   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     20.26
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           4.05e-05
# Time:                        13:27:05   Log-Likelihood:                -63.161
# No. Observations:                  52   AIC:                             130.3
# Df Residuals:                      50   BIC:                             134.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.1586      0.218     37.505      0.000       7.722       8.596
# predicted_ln_export_area    -0.2547      0.057     -4.501      0.000      -0.368      -0.141
# ==============================================================================
# Omnibus:                        0.231   Durbin-Watson:                   2.546
# Prob(Omnibus):                  0.891   Jarque-Bera (JB):                0.250
# Skew:                           0.144   Prob(JB):                        0.883
# Kurtosis:                       2.822   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2016:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2016   R-squared:                       0.278
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     19.27
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           5.87e-05
# Time:                        13:27:05   Log-Likelihood:                -63.550
# No. Observations:                  52   AIC:                             131.1
# Df Residuals:                      50   BIC:                             135.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.1155      0.219     37.029      0.000       7.675       8.556
# predicted_ln_export_area    -0.2503      0.057     -4.390      0.000      -0.365      -0.136
# ==============================================================================
# Omnibus:                        0.015   Durbin-Watson:                   2.489
# Prob(Omnibus):                  0.992   Jarque-Bera (JB):                0.065
# Skew:                          -0.017   Prob(JB):                        0.968
# Kurtosis:                       2.829   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2017:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2017   R-squared:                       0.295
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     20.89
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           3.22e-05
# Time:                        13:27:05   Log-Likelihood:                -63.771
# No. Observations:                  52   AIC:                             131.5
# Df Residuals:                      50   BIC:                             135.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.2047      0.220     37.277      0.000       7.763       8.647
# predicted_ln_export_area    -0.2617      0.057     -4.570      0.000      -0.377      -0.147
# ==============================================================================
# Omnibus:                        0.043   Durbin-Watson:                   2.516
# Prob(Omnibus):                  0.979   Jarque-Bera (JB):                0.135
# Skew:                          -0.063   Prob(JB):                        0.935
# Kurtosis:                       2.785   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2018:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2018   R-squared:                       0.255
# Model:                            OLS   Adj. R-squared:                  0.240
# Method:                 Least Squares   F-statistic:                     17.10
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000136
# Time:                        13:27:05   Log-Likelihood:                -65.358
# No. Observations:                  52   AIC:                             134.7
# Df Residuals:                      50   BIC:                             138.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.1931      0.227     36.105      0.000       7.737       8.649
# predicted_ln_export_area    -0.2441      0.059     -4.135      0.000      -0.363      -0.126
# ==============================================================================
# Omnibus:                        0.112   Durbin-Watson:                   2.477
# Prob(Omnibus):                  0.945   Jarque-Bera (JB):                0.288
# Skew:                          -0.080   Prob(JB):                        0.866
# Kurtosis:                       2.673   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2019:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2019   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.228
# Method:                 Least Squares   F-statistic:                     16.08
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000203
# Time:                        13:27:05   Log-Likelihood:                -64.861
# No. Observations:                  52   AIC:                             133.7
# Df Residuals:                      50   BIC:                             137.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.1435      0.225     36.232      0.000       7.692       8.595
# predicted_ln_export_area    -0.2345      0.058     -4.010      0.000      -0.352      -0.117
# ==============================================================================
# Omnibus:                        0.116   Durbin-Watson:                   2.435
# Prob(Omnibus):                  0.944   Jarque-Bera (JB):                0.294
# Skew:                          -0.078   Prob(JB):                        0.863
# Kurtosis:                       2.666   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2020:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2020   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.192
# Method:                 Least Squares   F-statistic:                     13.13
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000679
# Time:                        13:27:05   Log-Likelihood:                -63.015
# No. Observations:                  52   AIC:                             130.0
# Df Residuals:                      50   BIC:                             133.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        7.9763      0.217     36.770      0.000       7.541       8.412
# predicted_ln_export_area    -0.2045      0.056     -3.624      0.001      -0.318      -0.091
# ==============================================================================
# Omnibus:                        0.506   Durbin-Watson:                   2.355
# Prob(Omnibus):                  0.776   Jarque-Bera (JB):                0.649
# Skew:                          -0.182   Prob(JB):                        0.723
# Kurtosis:                       2.592   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Results for 2021:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LNYR2021   R-squared:                       0.207
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     13.03
# Date:                Mon, 29 Apr 2024   Prob (F-statistic):           0.000708
# Time:                        13:27:05   Log-Likelihood:                -63.926
# No. Observations:                  52   AIC:                             131.9
# Df Residuals:                      50   BIC:                             135.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.0817      0.221     36.609      0.000       7.638       8.525
# predicted_ln_export_area    -0.2073      0.057     -3.610      0.001      -0.323      -0.092
# ==============================================================================
# Omnibus:                        0.261   Durbin-Watson:                   2.385
# Prob(Omnibus):                  0.878   Jarque-Bera (JB):                0.405
# Skew:                          -0.145   Prob(JB):                        0.817
# Kurtosis:                       2.679   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
